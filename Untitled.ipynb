# %%
import pandas as pd

# %%
movies =  pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.duration>=200) & (movies.genre=='Drama')][['content_rating', 'star_rating']]
# Out:
#     content_rating  star_rating
# 17         UNRATED          8.7
# 157              G          8.2
# 476          PG-13          7.8

# %%
True or False
# Out:
# True

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies[(movies.genre=='Crime')|(movies.genre=='Action')|(movies.genre=='Drama')]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
movies[movies.genre.isin(['Crime','Action','Drama'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.loc[0:10,'City': 'State']
# Out:
#                     City Colors Reported Shape Reported State
# 0                 Ithaca             NaN       TRIANGLE    NY
# 1            Willingboro             NaN          OTHER    NJ
# 2                Holyoke             NaN           OVAL    CO
# 3                Abilene             NaN           DISK    KS
# 4   New York Worlds Fair             NaN          LIGHT    NY
# 5            Valley City             NaN           DISK    ND
# 6            Crater Lake             NaN         CIRCLE    CA
# 7                   Alma             NaN           DISK    MI
# 8                Eklutna             NaN          CIGAR    AK
# 9                Hubbard             NaN       CYLINDER    OR
# 10               Fontana             NaN          LIGHT    CA

# %%
ufo.head(6).drop('Time', axis=1)
# Out:
#                    City Colors Reported Shape Reported State
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
# 5           Valley City             NaN           DISK    ND

# %%
ufo.loc[ufo.City=='Oakland', ['State', 'Shape Reported']]
# Out:
#       State Shape Reported
# 1694     CA          CIGAR
# 2144     CA           DISK
# 4686     MD          LIGHT
# 7293     CA          LIGHT
# 8488     CA            NaN
# 8768     CA            NaN
# 10816    OR          LIGHT
# 10948    CA           DISK
# 11045    CA       TRIANGLE
# 12322    CA       FIREBALL
# 12941    CA       CYLINDER
# 16803    MD       TRIANGLE
# 17322    CA       CYLINDER

# %%
ufo.reset_index(inplace=True)

# %%
ufo.set_index(['City','State'])
# Out:
#                             level_0  index Colors Reported Shape Reported  \
# City                 State
# Ithaca               NY           0      0             NaN       TRIANGLE
# Willingboro          NJ           1      1             NaN          OTHER
# Holyoke              CO           2      2             NaN           OVAL
# Abilene              KS           3      3             NaN           DISK
# New York Worlds Fair NY           4      4             NaN          LIGHT
# Valley City          ND           5      5             NaN           DISK
# Crater Lake          CA           6      6             NaN         CIRCLE
# Alma                 MI           7      7             NaN           DISK
# Eklutna              AK           8      8             NaN          CIGAR
# Hubbard              OR           9      9             NaN       CYLINDER
# Fontana              CA          10     10             NaN          LIGHT
# ...

# %%
# Out:
#        index                  City Colors Reported Shape Reported State  \
# 0          0                Ithaca             NaN       TRIANGLE    NY
# 1          1           Willingboro             NaN          OTHER    NJ
# 2          2               Holyoke             NaN           OVAL    CO
# 3          3               Abilene             NaN           DISK    KS
# 4          4  New York Worlds Fair             NaN          LIGHT    NY
# 5          5           Valley City             NaN           DISK    ND
# 6          6           Crater Lake             NaN         CIRCLE    CA
# 7          7                  Alma             NaN           DISK    MI
# 8          8               Eklutna             NaN          CIGAR    AK
# 9          9               Hubbard             NaN       CYLINDER    OR
# 10        10               Fontana             NaN          LIGHT    CA
# 11        11              Waterloo             NaN       FIREBALL    AL
# ...

# %%
ufo.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-3628ae3e8cf2> in <module>
# ----> 1 ufo.reset_index(inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4137                 # to ndarray and maybe infer different dtype
#    4138                 level_values = _maybe_casted_values(lev, lab)
# -> 4139                 new_obj.insert(0, name, level_values)
#    4140
#    4141         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
# -> 3222                           allow_duplicates=allow_duplicates)
#    3223
#    3224     def assign(self, **kwargs):
#
# ...
