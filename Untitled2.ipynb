# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ufo = pd.read_csv('weatherHistory.csv')

# %%
ufo.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
ufo["Daily Summary"].unique().shape
# Out:
# (214,)

# %%
ufo.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
ufo.driver_gender.value_counts()
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
ufo.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
ufo.shape
# Out:
# (91741, 15)

# %%
ufo.driver_race.value_counts()
# Out:
# White       62158
# Black       12244
# Hispanic     9507
# Asian        2259
# Other         240
# Name: driver_race, dtype: int64

# %%
pd.crosstab(ufo.violation, ufo.driver_gender,  normalize=True).plot(kind='bar')

# %%
pd.crosstab(ufo.driver_race, ufo.search_conducted,  normalize=True).plot(kind='bar')

# %%
ufo['stop_date'] = pd.to_datetime(ufo['stop_date'])

# %%
ufo.stop_date.dt.year.value_counts()
# Out:
# 2012    10970
# 2006    10639
# 2007     9476
# 2014     9228
# 2008     8752
# 2015     8599
# 2011     8126
# 2013     7924
# 2009     7908
# 2010     7561
# 2005     2558
# Name: stop_date, dtype: int64

# %%
ufo['year'] = pd.DatetimeIndex(ufo['stop_date']).year
ufo.head()
ufo.year.value_counts()
# Out:
# 2012    10970
# 2006    10639
# 2007     9476
# 2014     9228
# 2008     8752
# 2015     8599
# 2011     8126
# 2013     7924
# 2009     7908
# 2010     7561
# 2005     2558
# Name: year, dtype: int64

# %%
ufo['Time'] = pd.to_datetime(ufo['stop_date']).dt.time
ufo.head()
ufo.Time.value_counts()
# Out:
# 00:00:00    91741
# Name: Time, dtype: int64

# %%
ufo['stop_time'] = pd.to_datetime(ufo['stop_time'])
ufo.groupby(ufo.stop_time.dt.hour).drugs_related_stop.mean().plot(kind='bar')

# %%
pd.crosstab(ufo.Time, ufo.drugs_related_stop,  normalize=True)
# Out:
# drugs_related_stop     False     True
# Time
# 00:00:00            0.991116  0.008884

# %%
ufo.stop_date.value_counts()
# Out:
# 2012-01-11    69
# 2012-02-28    65
# 2007-05-16    62
# 2012-01-02    61
# 2007-01-10    60
# 2006-05-21    58
# 2015-10-31    58
# 2006-02-09    55
# 2012-01-28    54
# 2005-11-04    54
# 2012-07-21    54
# 2006-06-13    54
# 2007-01-17    54
# 2011-11-25    53
# 2012-02-04    53
# 2014-02-23    53
# 2006-08-04    53
# 2007-02-13    53
# 2006-08-07    52
# 2012-04-16    52
# 2012-03-30    52
# 2012-06-03    51
# 2012-03-02    51
# 2006-01-12    51
# 2005-11-05    51
# 2015-09-05    51
# 2005-10-29    51
# 2012-05-10    51
# 2012-01-14    51
# 2005-11-27    50
#               ..
# 2010-12-26     2
# 2009-12-20     2
# 2012-10-29     2
# 2011-02-01     2
# 2009-12-25     2
# 2005-06-06     1
# 2012-12-25     1
# 2010-12-25     1
# 2005-09-03     1
# 2005-07-20     1
# 2005-02-20     1
# 2005-12-25     1
# 2005-08-28     1
# 2005-09-22     1
# 2005-04-01     1
# 2005-01-18     1
# 2015-01-27     1
# 2005-08-07     1
# 2005-07-14     1
# 2005-01-23     1
# 2005-09-17     1
# ...

# %%
ufo.dtypes
# Out:
# stop_date             datetime64[ns]
# stop_time             datetime64[ns]
# county_name                  float64
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# search_type                   object
# stop_outcome                  object
# is_arrested                   object
# stop_duration                 object
# drugs_related_stop              bool
# year                           int64
# Time                          object
# dtype: object

# %%
ufo.head()
# Out:
#    stop_date           stop_time  county_name driver_gender  driver_age_raw  \
# 0 2005-01-02 2019-07-29 01:55:00          NaN             M          1985.0
# 1 2005-01-18 2019-07-29 08:15:00          NaN             M          1965.0
# 2 2005-01-23 2019-07-29 23:15:00          NaN             M          1972.0
# 3 2005-02-20 2019-07-29 17:15:00          NaN             M          1986.0
# 4 2005-03-14 2019-07-29 10:00:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
# ...

# %%
ufo.pivot_table(index = 'violation', columns = 'driver_gender', aggfunc = 'sum')
# Out:
#                     county_name      driver_age            driver_age_raw  \
# driver_gender                 F    M          F          M              F
# violation
# Equipment                   0.0  0.0    78300.0   271519.0      4918905.0
# Moving violation            0.0  0.0   108486.0   475358.0      6318628.0
# Other                       0.0  0.0    23269.0   142944.0      1354188.0
# Registration/plates         0.0  0.0    33245.0    79171.0      2001874.0
# Seat belt                   0.0  0.0    19129.0    75944.0      1259815.0
# Speeding                    0.0  0.0   502671.0  1118828.0     30573353.0
#
#                                 drugs_related_stop        search_conducted  \
# driver_gender                 M                  F      M                F
# violation
# Equipment            16873517.0               20.0  195.0            106.0
# Moving violation     25609741.0               30.0  221.0            116.0
# ...

# %%
ufo.isna
# Out:
# <bound method DataFrame.isna of        stop_date           stop_time  county_name driver_gender  \
# 0     2005-01-02 2019-07-29 01:55:00          NaN             M
# 1     2005-01-18 2019-07-29 08:15:00          NaN             M
# 2     2005-01-23 2019-07-29 23:15:00          NaN             M
# 3     2005-02-20 2019-07-29 17:15:00          NaN             M
# 4     2005-03-14 2019-07-29 10:00:00          NaN             F
# 5     2005-03-23 2019-07-29 09:45:00          NaN             M
# 6     2005-04-01 2019-07-29 17:30:00          NaN             M
# 7     2005-06-06 2019-07-29 13:20:00          NaN             F
# 8     2005-07-13 2019-07-29 10:15:00          NaN             M
# 9     2005-07-13 2019-07-29 15:45:00          NaN             M
# 10    2005-07-13 2019-07-29 16:20:00          NaN             M
# 11    2005-07-13 2019-07-29 19:00:00          NaN             F
# 12    2005-07-14 2019-07-29 19:55:00          NaN             M
# ...

# %%
ufo.dtypes
# Out:
# stop_date             datetime64[ns]
# stop_time             datetime64[ns]
# county_name                  float64
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# search_type                   object
# stop_outcome                  object
# is_arrested                   object
# stop_duration                 object
# drugs_related_stop              bool
# year                           int64
# Time                          object
# dtype: object

# %%
ufo.describe()
# Out:
#        county_name  driver_age_raw    driver_age          year
# count          0.0    86414.000000  86120.000000  91741.000000
# mean           NaN     1970.491228     34.011333   2010.267699
# std            NaN      110.914909     12.738564      3.029080
# min            NaN        0.000000     15.000000   2005.000000
# 25%            NaN     1967.000000     23.000000   2008.000000
# 50%            NaN     1980.000000     31.000000   2010.000000
# 75%            NaN     1987.000000     43.000000   2013.000000
# max            NaN     8801.000000     99.000000   2015.000000

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 17 columns):
# stop_date             91741 non-null datetime64[ns]
# stop_time             91741 non-null datetime64[ns]
# county_name           0 non-null float64
# driver_gender         86406 non-null object
# driver_age_raw        86414 non-null float64
# driver_age            86120 non-null float64
# driver_race           86408 non-null object
# violation_raw         86408 non-null object
# violation             86408 non-null object
# search_conducted      91741 non-null bool
# search_type           3196 non-null object
# stop_outcome          86408 non-null object
# is_arrested           86408 non-null object
# stop_duration         86408 non-null object
# drugs_related_stop    91741 non-null bool
# year                  91741 non-null int64
# Time                  91741 non-null object
# dtypes: bool(2), datetime64[ns](2), float64(3), int64(1), object(9)
# ...
