# %%
import pandas as pd

# %%
drinks = pd.read_csv(r"C:\Users\sunny\Desktop\bitly\drinks.csv")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %% [markdown]
# ### indices are there for three reasons 1. identification 2. selection 3. alignmnet

# %% [markdown]
# ## 1. identification

# %%
drinks[drinks.continent == 'South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
drinks.loc[6]
# Out:
# country                             Argentina
# beer_servings                             193
# spirit_servings                            25
# wine_servings                             221
# total_litres_of_pure_alcohol              8.3
# continent                       South America
# Name: 6, dtype: object

# %% [markdown]
# ## 2. Selection

# %%
drinks.loc[23, 'beer_servings']
# Out:
# 245

# %%
drinks.set_index('country', inplace = True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.loc['Brazil', 'beer_servings']
# Out:
# 245

# %%
# remember index and columns are not a part of the data frame
drinks.shape
# Out:
# (193, 5)

# %%
drinks.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinks.index.name = None

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index.name = 'country'
drinks.reset_index(inplace = True)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ## 3. Alignment

# %%
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: object

# %%
drinks.set_index('country', inplace = True)

# %%
drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
type(drinks.continent.value_counts())
# Out:
# pandas.core.series.Series

# %%
drinks.continent.value_counts().index
# Out:
# Index(['Africa', 'Europe', 'Asia', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
drinks.continent.value_counts()['Africa']
# Out:
# 53

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drinks.continent.value_counts().sort_values(ascending = False)
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().sort_index(ascending = False)
# Out:
# South America    12
# Oceania          16
# North America    23
# Europe           45
# Asia             44
# Africa           53
# Name: continent, dtype: int64

# %%
# now comming to alignment 
people = pd.Series([3000000,85000], index = ['Albania', 'Andorra'], name = 'population')
people
# Out:
# Albania    3000000
# Andorra      85000
# Name: population, dtype: int64

# %%
drinks.beer_servings * people
# Out:
# Afghanistan                     NaN
# Albania                 267000000.0
# Algeria                         NaN
# Andorra                  20825000.0
# Angola                          NaN
# Antigua & Barbuda               NaN
# Argentina                       NaN
# Armenia                         NaN
# Australia                       NaN
# Austria                         NaN
# Azerbaijan                      NaN
# Bahamas                         NaN
# Bahrain                         NaN
# Bangladesh                      NaN
# Barbados                        NaN
# Belarus                         NaN
# Belgium                         NaN
# Belize                          NaN
# Benin                           NaN
# Bhutan                          NaN
# Bolivia                         NaN
# Bosnia-Herzegovina              NaN
# Botswana                        NaN
# Brazil                          NaN
# Brunei                          NaN
# Bulgaria                        NaN
# ...

# %%
pd.concat([drinks, people], axis =1, sort = False).head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe   3000000.0
# Algeria                               0.7    Africa         NaN
# Andorra                              12.4    Europe     85000.0
# Angola                                5.9    Africa         NaN

# %% [markdown]
# ## Multilevel Indexing

# %%
stocks = pd.read_csv('http://bit.ly/smallstocks')

# %%
stocks
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
stocks.set_index(['Symbol', 'Date'], inplace = True)

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# CSCO   2016-10-03   31.50  14070500
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500
# AAPL   2016-10-04  113.00  29736800
# MSFT   2016-10-04   57.24  20085900
# CSCO   2016-10-04   31.35  18460400
# MSFT   2016-10-05   57.64  16726400
# CSCO   2016-10-05   31.59  11808600
# AAPL   2016-10-05  113.05  21453100

# %%
stocks.sort_index(inplace = True)

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
stocks.loc['AAPL']
# Out:
#              Close    Volume
# Date
# 2016-10-03  112.52  21701800
# 2016-10-04  113.00  29736800
# 2016-10-05  113.05  21453100

# %%
stocks.loc[('AAPL', '2016-10-03'), :]
# Out:
# Close          112.52
# Volume    21701800.00
# Name: (AAPL, 2016-10-03), dtype: float64

# %%
stocks.loc[(['AAPL', 'MSFT'], '2016-10-03'),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500

# %%
stocks.loc[('AAPL', ['2016-10-03', '2016-10-04']),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800

# %%
stocks.loc[(['AAPL', 'MSFT'], ['2016-10-03', '2016-10-04']),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900

# %%
stocks.loc[(slice(None), ['2016-10-03', '2016-10-04']),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900

# %% [markdown]
# ## Sorting data

# %%
drinks
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# Armenia                          21              179             11
# Australia                       261               72            212
# Austria                         279               75            191
# Azerbaijan                       21               46              5
# Bahamas                         122              176             51
# Bahrain                          42               63              7
# ...

# %%
drinks.reset_index(inplace = True)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.set_index(['continent', 'country'], inplace = True)

# %%
drinks.sort_index(inplace = True)

# %%
drinks.head
# Out:
# <bound method NDFrame.head of                                         beer_servings  spirit_servings  \
# continent     country
# Africa        Algeria                              25                0
#               Angola                              217               57
#               Benin                                34                4
#               Botswana                            173               35
#               Burkina Faso                         25                7
#               Burundi                              88                0
#               Cabo Verde                          144               56
#               Cameroon                            147                1
#               Central African Republic             17                2
#               Chad                                 15                1
#               Comoros                               1                3
# ...

# %%
drinks.sort_index(level = 'country')
# Out:
#                                     beer_servings  spirit_servings  \
# continent     country
# Asia          Afghanistan                       0                0
# Europe        Albania                          89              132
# Africa        Algeria                          25                0
# Europe        Andorra                         245              138
# Africa        Angola                          217               57
# North America Antigua & Barbuda               102              128
# South America Argentina                       193               25
# Europe        Armenia                          21              179
# Oceania       Australia                       261               72
# Europe        Austria                         279               75
#               Azerbaijan                       21               46
# North America Bahamas                         122              176
# Asia          Bahrain                          42               63
# ...

# %%
drinks.sort_index(level = 'continent', ascending = False)
# Out:
#                                         beer_servings  spirit_servings  \
# continent     country
# South America Venezuela                           333              100
#               Uruguay                             115               35
#               Suriname                            128              178
#               Peru                                163              160
#               Paraguay                            213              117
#               Guyana                               93              302
#               Ecuador                             162               74
#               Colombia                            159               76
#               Chile                               130              124
#               Brazil                              245              145
#               Bolivia                             167               41
#               Argentina                           193               25
# ...

# %%
drinks.sort_index(axis = 1, ascending = False)
# Out:
#                                         wine_servings  \
# continent     country
# Africa        Algeria                              14
#               Angola                               45
#               Benin                                13
#               Botswana                             35
#               Burkina Faso                          7
#               Burundi                               0
#               Cabo Verde                           16
#               Cameroon                              4
#               Central African Republic              1
#               Chad                                  1
#               Comoros                               1
#               Congo                                 9
#               Cote d'Ivoire                         7
#               DR Congo                              1
#               Djibouti                              3
#               Egypt                                 1
# ...

# %%
drinks.sort_values(by = 'beer_servings', ascending = False)
# Out:
#                                   beer_servings  spirit_servings  \
# continent     country
# Africa        Namibia                       376                3
# Europe        Czech Republic                361              170
# Africa        Gabon                         347               98
# Europe        Germany                       346              117
#               Lithuania                     343              244
#               Poland                        343              215
# South America Venezuela                     333              100
# Europe        Ireland                       313              118
# Oceania       Palau                         306               63
# Europe        Romania                       297              122
#               Belgium                       295               84
# North America Panama                        285              104
# Europe        Spain                         284              157
# ...
